# %%
from repenseai.genai.agent import Agent
from repenseai.genai.tasks.api import Task

from repenseai.genai.tasks.workflow import Workflow

# Speech-To-Text

sst_agent = Agent(
    model="whisper-1",
    model_type="audio",
)

sst_task = Task(
    agent=sst_agent,
    audio_key="my_audio",
    simple_response=True
)

# Reasoning

reasoning_agent = Agent(
    model="gpt-4o",
    model_type="chat",
)

reasoning_task = Task(
    user=(
        "Você vai receber uma chamada para ação,"
        "por favor, faça melhorias usando as melhores"
        "práticas de pitch de vendas.\n\n"
        "CTA: {transcript}\n\n"
        "Responda apenas com a mensagem melhorada, sem explicações ou contextos"
    ),
    agent=reasoning_agent,
    simple_response=True,
)

# Text-To-Speech

tts_agent = Agent(
    model="tts-1-hd",
    model_type="speech",
    voice="shimmer"
)

tts_task = Task(
    agent=tts_agent,
    speech_key="speech",
    simple_response=True
)

# Workflow

workflow = Workflow(
    [
        [sst_task, "transcript"],
        [reasoning_task, "speech"],
        [tts_task, "output"]
    ]
)

# Execução

my_audio = open("assets/deixa_o_like.mp3", "rb")
response = workflow.run({"my_audio": my_audio})

speech = response["output"]
# Out:
# 2025-04-13 09:47:45 - INFO - HTTP Request: POST https://api.openai.com/v1/audio/transcriptions "HTTP/1.1 200 OK"
# 2025-04-13 09:47:47 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-04-13 09:47:50 - INFO - HTTP Request: POST https://api.openai.com/v1/audio/speech "HTTP/1.1 200 OK"

# %%
from IPython.display import Audio
display(Audio(speech, autoplay=False, rate=24000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
response
# Out:
# {'my_audio': <_io.BufferedReader name='assets/deixa_o_like.mp3'>,
#  'transcript': 'E aí, pessoal? Vamos deixar um like nesse vídeo? Muito obrigado!',
#  'speech': 'Ei, pessoal! Se você gostou deste conteúdo, não esqueça de dar um like no vídeo. Isso nos ajuda muito. Obrigado!',
#  'output': b'\xff\xf3\xe4\xc4\x00d\xec9\xa8\x03[\xc8\x02!\xbe8\x1a\xa1pXt\xd2\xdbN\x16T\xe7f\xceN\x04\xdaR\xc1\xc8\xe6\x12Be%fNBc\xa3&*\x1e\x06\x0fgF\x00 c\xc4\x06vrg&\xa6bVd\xa4&:2b\xa2&\x1a\x16aaf\x1a\x16k$h\x18c\x00\x82\x8c\xb2\x1cv\x18b\xecT\xe9\x8e\x84\xb4\x03\xa0\x1d"\xd3\x1c\xbf\xe6\x08&QFQ\x06 \x05\xd8m\x1d5N\xf3\x16\xe0\xcf4\x0c{l\xb0\x8fis\xcc\xb4\xcd\x98Nx\xcfK\x8e\xea\x8eG\x8d\x84\x8d\x03\x0c\xc2\x8c`\x14\xe0\x12\x19\xb0\xd1\xb4\xa1\xa0Q\x88\x11\x80\x01\x80\x00\x08\x02\xcc"\x82E\xa4:+\xa4Z\xc7q\xe5L\x00\xbb\x86(f\x18%\xc7Sv\xbf\x0f\xc3l\xad1\xcbh^\x04\x88LD\x84@!r\x0b\x90^\x02\xd1\x97\x8d\x15\xd4\x1dw\xae\xf5\x87P4\x8b.Ar\x0b\x90\x80D\x88X\x8e\xe5+\xb6\xa9\x16#\xf1U\xf7km}\xdf\x97\xe3+\x86\xdf\xf7\xfe~P\xca\x11P\xb3e\xb7A\xf5\x07bm}\xdf\x9ev\x15:\x83\xb18\xbd\x03\xb0\xc3\x18\x83\x88\xef\xb9l\xed\x9d\xa8;/\x97\xe7+v\x1c\x87q\xfc\x8cRr\xbcm\xc8r\x1c\x87\xf2Y\xb9[\x86\xbb\xd2!A\x19d\xeb\x86\xb0\xe9\x8e\xa9\xe1\xf8\xc5%\x8d\xca\xe3q\xbb\xf0\xc3\x0fbn\xfd\xa8a\x86,"\xa4PD\x8bT\xeb\xbd\x9d\xb9n[\xff/\xb8\xff\xb9n[\xbf/\xb8\xfe9\x0f\xe3\xfe\xff\xb9mm\x9d\xb3\xb7~~P\xd6\xd9\xdb;gm}\xdf\x97\xc7\x17b\x01\xd0}A\xda\xfc?/\xa7\xa7\x8d\xbf\x8f\xe49b\xbc6\xed\xb9o\xfa\x02 \x84\x00B`\rH\xc2\xd3\x98\x08\x80\xb9\x89I+\x99~\xa4h\x18\x04\x11P\xc0d\x0b\xcc\x12\x00,\xce\xdcuN~\x8f\xc9:\'\x8c\t\xc1P\xc2\xc0\x14\x8daT\xf4\xcb<q\xdf\x8a\xb2\xf3\x03\xe0\x02T\xff\xf3\xe4\xc4?v\x1c:,\xe9\x9e\xf0\x00F\x01\x80\x14c\xc4\x1e\x06\x0f\xc1d<\x07\xb28s:p\xa8\x01\x18\x01\x00@\x08\x0c\x03\x00 \xc0\xc0\n\xc0A\xb6`*\n\xe6\n\xe0\xbb1 i\xf1\x07q\xd2G\xc3\x01P\x1b\x1e\x03\xf3\x01\x00\n0U\x05\xb0P#\x98P\x01\xe1\x83\xd0\x9d\x18h\t\xfaI\xc3r\xf9\x0b\x86\xef\x98\xbc\t\x01\x80`}\x98\x9f\x85)\x86\xa8\'\x98&\x03Q\x10\x1a\x99\xd6\x89\xd0\x1a\xfdL\xbc\xc2\x80\xc9\x14\x8e\x8c4\x08\xb8\xcf\x18\x8e\x16\xa4b)\x0f\xd3\xcf\xbb\x86\x06!\x16`\xf2\x04\x06\x13\x80\xaca\xd0\x19\xc6\n\xc0\xf2a\xa2\r\xe6)!*e\xf0*\xe6-\xa4\xe0`\xbeL&Ub\na\xc0V\xa6\x14\xe5pc\x8a8Q\x89\xcb3\xf8wy\xf0\xc1\x00\r\x0c\r@\xd4\x04\x13\x06\x00`\x04`X\x02\x88h\xaai\xae\xb1\xcc\xbdM\xe4\xc60m\x0c\t\x07\x04\xc5T/\x8c\x18\x81\x9c\xc0\xf4\x08@@J\x10\x02Qo\xe7\xffs\xfe\xeb\xff\xdd\xa6X\xeb;,\x9d5\xe5O\xc4S\xbf\x89\x80\xc8\x01>\xa2\x804\x16\x003\x02\xc0@0\x00\x00\x03\x00`(\x0e\x05\x03\x00\x10\x01.\x03\xd64\x02\x1d\xff\xff\xff\xfd\x7f\xff\xff\xfd\xbc5\xce\xe3o\xeb5\x87R\x18r!\xc9\x7f`\x87~L\xff\xc5#\xac\x02\xd2C \x8cB\x00a\xc00`"\x00b@\x01\r\xb5?\xfd\x7f\x7f\xf9\xaf\xff\xff\xff\xef\xff\xef\xf9I\x8es\xf69f\x1b\x8b\xea\x18\x96C\x94\x92\xcdo\xa1\x80\x01%\x9f\x94\xceb\xfa5zxBi\xb5\xc5\xa1\x16}\x12\xa5q\x83\x00!\xb4*\x80\td\xcb\x00\x0e`\x14\x00!\xc0 V\x00u\xa4\x10\x00\x00\n\x03\x00\xc1\xb3\x04\xd3S\xdc\xc1\xa3\xec\xcaQ\xf8\xc2!t\xdc\xa3\x98\xdb\x10\x00\xcfe\xf4\xebB\\\xc7\xbb \xdf\x10\x00\xcfZ\xd4\xd3 \x88\xc1\x10x\xc3\x15\xa8\xc6ax\xcaB\xff\xf3\xe4\xc49n\xb4:lg\x9d\xd8\x00d\xc8\xe0x\xcc\t\x8c\xf1(\xd5\rL\x8cH@\x06\x06\x03\x12P\x01\x1d\x180\x92\xeb]\xa9\x86\x9e\x00\x00$\xbfZ\xe9\x82\x93\x8cA5\x8a\x03\x90BT\x070\x80\xc0\xa0pp\xe9m\xd5\x01\x80\x80\x05K\x8c\x05Y\t\x8a\xa2\x0e)\x0e#0\x84c\x15T=4\xa37\xa35\x88\xc3\x07|\x1a\x980\xe0\xd3\xfc\x1f?\xa5\xa3\x95\x1e\n\xd6\x1a\x93\x81\x91\x0b\x19\xc6\xd9\xc1\xc1\x9a}\t\xa6C\x1c\xc0\xf1\xcf\x90\x9bH\x89\x97\x88\x9911)\x90\xa1A\x12\xd9\xd1\xa2\x946\x84J\x18\xcaA\x84<\x02\x19\x0c0\x04\xef\x8e\x8cQ\x8c\xceJ\x02\x1f\x8dp\x80\xa2\xbc\xc9\x93H\x92\xc0\xcbFPX \x0cv\x1bh\x12\x10\xe9\x9c\xa0p\xd9\xa09\xcc\x088\x06 ]\x88\xe0\xb9\xcb\x90\x11\x9e0t<\x9c\x10\xc2\n\x1bX\x14\x103&\x82\xe5\xc0\xee\xc3\xa8\xfa\xafuw\x11k\x160\xe3Lq\xd6#\x07TH\xda\xbe\xd7\x9b\xe5/\x90\xdf\x0e\x02\x92.U~\x1c0`aE\xd00\x10r`\xc4Zz,\xcd\xd9\x9e\xce\xad\x8cq\x95\xb36\xec\x97i\x9e\xdfI\xa8\xa8()\xe5\x92j\xd2\x8dF\x1f\x8aF\x00\xc4%W\xa40\\\xfdx\xa6_O\x1a\x973\x06\xbc\xda\xc6\xe1\xe8F\xf1\xa4\xa4\xa2q\xdf\xfbs\x8f\xc4\x85\x97\xb0\xf6n\x98\x89x\xbc\x10\xdd\x7f\xa23\xf1\x10\x7f\xa9kV\xad+\xb1&\xbf*\xb1=\x18\x8cV\xce^\xee9\x12\x18\x029\xfa\xb1\xbb\x97\xe4\xd1\xb8v\xd49\x8di$\xe3\xf75\x1a\x86\x1a\x1cf=y@\x12\x82\xa1P8\xc0p\x80 ...
