# %%
from repenseai.genai.agent import Agent
from repenseai.genai.tasks.api import Task

from repenseai.genai.tasks.workflow import Workflow

# Speech-To-Text

sst_agent = Agent(
    model="whisper-1",
    model_type="audio",
)

sst_task = Task(
    agent=sst_agent,
    audio_key="my_audio",
    simple_response=True
)

# Reasoning

reasoning_agent = Agent(
    model="gpt-4o",
    model_type="chat",
)

reasoning_task = Task(
    user=(
        "Você vai receber uma chamada para ação,"
        "por favor, faça melhorias usando as melhores"
        "práticas de pitch de vendas.\n\n"
        "CTA: {transcript}\n\n"
        "Responda apenas com a mensagem melhorada, sem explicações ou contextos"
    ),
    agent=reasoning_agent,
    simple_response=True,
)

# Text-To-Speech

tts_agent = Agent(
    model="tts-1-hd",
    model_type="speech",
    voice="shimmer"
)

tts_task = Task(
    agent=tts_agent,
    speech_key="speech",
    simple_response=True
)

# Workflow

workflow = Workflow(
    [
        [sst_task, "transcript"],
        [reasoning_task, "speech"],
        [tts_task, "output"]
    ]
)

# Execução

my_audio = open("assets/deixa_o_like.mp3", "rb")
response = workflow.run({"my_audio": my_audio})

speech = response["output"]
# Out:
# 2025-04-13 08:38:39 - INFO - HTTP Request: POST https://api.openai.com/v1/audio/transcriptions "HTTP/1.1 200 OK"
# 2025-04-13 08:38:41 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-04-13 08:38:43 - INFO - HTTP Request: POST https://api.openai.com/v1/audio/speech "HTTP/1.1 200 OK"

# %%
from IPython.display import Audio
display(Audio(speech, autoplay=False, rate=24000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
response
# Out:
# {'my_audio': <_io.BufferedReader name='assets/deixa_o_like.mp3'>,
#  'transcript': 'E aí, pessoal? Vamos deixar um like nesse vídeo? Muito obrigado!',
#  'speech': 'Ei, pessoal! Se você gostou deste conteúdo, não esqueça de deixar seu like e se inscrever no canal. Sua participação é super importante para nós! Muito obrigado!',
#  'output': b'\xff\xf3\xe4\xc4\x00X\x0c9\xe0\xf7Xx\x00 \x0b\x0f\xe3\x9a\x99\x04_\x08e/\xd0\x0e\x98l\xbd\xad\xa2yr\x13\x01\xd4\xc2 \xb9\x12\x11\x07\x14\xd1\x97\xb9l\xed\x9d\xae\xf5\xde\xbb\xd8\x9b\x8et!\x86\x81\xa0h!\x86\x82\x18t\x173\xad\x0fC\xc88\xb7\x89\xb8\xb9\xaa\xd8\xdc\xe0j\x1b\x1b=\x93\x84\xecz\xc7\xacM\xc4\xdcz\xc8Ys:\xcb\x81\xa0\x86(\x19\x14\n\xc5b\x80\xd34\xcd3L\xd34\xcd3L\x9d\x8fA\x084\x10\xc40\xd0-\x84\xe0\xb8\x1ae\xbc\x9d\x90\xb2vi\xa1\xe79;\x10\xc14\x1e\x82pN\t\xc18\'\x04\xe0z\xc9\xd9;4\xcd3L\x9d\x972\x16B\t\xc18\'\x06\x81\xa0h\x1a\x06\x81\x0b\'d\xec\x9d\x93\xb2vN\xcb\x99\xd6h\x1a\x05\xb0\x9c\x1a\x05\xb0\x9c\x1a\x07A\xd6i\x9af\x9a\x1e\x87\xa1\xe8y\xa6N\t\xc18.\x06\x81\xa0h\x1a\x07A\xa6i\x9ahy\xd6\x87\xa1\xe8z\x1e\\\r\x03@\xd04\t\xc184\x0e\x83\xac\xd3-\xe4\xecz\xc7\xac\x9d\x9aj5b\xb1X\xacd\x89\xfb\xc5z\x8d\x0f-\xe2\xde\x1a\xb0s\x86\xac\\\xc8ApPEcC\xd0\xf5{;#\xcdCO\x96\xf2\x0e=d,z\x08A84\r\x040\xd0C\x10\xc3\xac\xe74\xcby\x07\x1e\xb1\xeb\'h[#\x02q\x0c4\x0ba8\'\x05\xc0\xb9\x93\xb2v=c\xd6=d\xec\x9d\x9df\x81l\'\x03\xd0B\t\xc1\xa0\x862*\x02\x08\xc0\x00@p,\x96P\xc0(\x18\x8c\r\x00\xc0\xc1\x9c\x10\x81\x81\xf6\x90\xa6\x01\xe0\x12`\x98\x05F2\x80\x8cbZ2\xe6W\xea\x1e\x14\x03\xa00 \x04\x159\x850\x02\x18\xd2\t\xd1\x818\x88\x84\x00\xc3u\x8e\r\x08H\x8c\x03\x8c\x03\x80\x08\xc3\xcc\x1fL%\x03p\xc0P\x10U\x13\xa9\x18-\xe1\x81\xd8\x11\x98\x00\x80\xc0\x04\x06\xc7\x00\xac\xc1\x00"\x8c\x04\x01DP\x05C\x83]\xa2\xff\xf3\xe4\xc4r{4:\x14\xe9\x9e\xf0\x00\xb9\xeaP2\x01\xe0\xa03\x11\x80\xc8`)\x98\t\x81!\x81\x10Y\x987\x83Q\x84(Q\x983\x85a\x88\x98\xad\x18\x96\x8e\x99\x9a\xf2\x82\x18"\x80\xd9\x80 \x0b\x0b\x00 \x18\r\x0b\xce\xd4\xcc\x8c\xc2\x8c\xc1\x9c\x03\x0c\x12\x00\x94\xc0\xd0:L(\xc1\x18\xc3\x08\'\x8c\xf6\xcc\xd0\xc9D\x9b\xcc\xa6\x08\x10\xcc\x18\xe4\xccE\xd2\xa0\xc5\xf4\xecB\x00N0\xff\xd2\xc4\xa5\x91s\x0e \xd4,\x05\x99\x86\x08&\x98\x80\x83\xf9\x80\xe0\x1f\x18\x02\x80\xa9\x81\xd06\x18\xae\x01Q\x91\xf0P\x98$\x90\xa0\x00\xad\x0c^D\x84\xccH\x88\x8c\xeb\x82}\xfc\x89\xa6\x1c5\x14e\x91\xfbN\xf9\x84\x00G\x18P\x02\xe1\x81H\x1b\x98"\x80\x088\x07\x0c\r\x80x\xa0\x06\x03\x80-2\x00L\x84f\x943\x060\x81\xfaa\xa6\x10\x86\x03\xe1\x9e`\xde\x01\x86\x07@\xbe\x14\x03\xe0\x10\r\xccK(\xa5v\xe7\xf2\xdf\xfe\x7fQ\xb9\x82@\x15\x97\xb8\xc0\xc0\x02d\x92\xc9~\xb3~\xc1\xa0\x06"\x00\xe3\x00\x10\x050!\x00 \xa8\x0b\x93\x01\x92\x06\xc4\xa2\xcf\x0bH\x820\xe6\xb5\xf9\xe1\x8d\x8d\xda\xde\xf0\xd65\xe9\xec\xd3\xe5?\xd9\xdeK`y4?z[\x1b\xb5(\x9b\x95\xb8\xce4\x1fz\x00p\xcb\xb0 \x00\x92\xf6\x17}\xdd]\x19U\xc7\xf0\xc7\x0f\xe7\xfe\xee~\x19\xf7\r~8\xda\xb7\x85\x9f\xd6<\xee{\xc3\xf0\xd7\xd2]\xbfOOR/5\x1d\xe4?RW\xfc\xb9\xa8\xbc\xad\xdc\xab\r\x98\x06\x00\x81\x80\x90\x00Q\x17\xe1\xe0\xc6\x01\x08\x0c\x0bA\xb4\xc2\x1cML\x05G\x1c\xc4$<\x80\xc1\xdah\xc8#\x86(\xa1\x12`\xa4\x11\xe62\xc6\x00e\xce\xc1\xe6I\xa3\xf2`\xc8\xda\xe6!b\xc6b\x1e\x0c\xa6\x1faZa\xba\r\x06Z\xe2\x16`H\r\xa6"\x16\x18H(YS\x1d\x1a\xcc>\x18\x01\x15B\r\xa6\x1d\x02\x98p&\x90\xff\xf3\xe4\xc4X{\x9c:T\x05\x9e\xe0\x00+\xa5\x80\x15A`\xe1\xb8$,2\x180H\x05UL\x00\x07\x0b\x04\x81\xc0\x81\xd088\\d!\xb1\x88\x90F\xba+\x00\x87\x84J\x00)\xf0\xcf\x0bCqPA@C"\x8b\x8c\x1471j\xc8\xc3\xee!\x100\xca\xc1C\x07\x85\x0c\xd2E3\x19L\xcdf\xf3\xd2\xb6\xccZ:1@\xa8\xd9\xeb3Q\x85\xcd\x1a\xb0;0H\x93*b\xa19\xb0BG.o\x98Z\x16aq\xd9\x90\xc4f\'\x17\x990 \n\x02\x08\xc1\xc6\\7\x10\x9d\xcc\xf6\x891\xc8\x80\x80\xf6@\xd10!\x84\xd3\x80s>\x03\x8c\x82B4a\x84\xc3\xc6# \x94\xcc`\x134\xe9 \xc5\x01e\xd8b`\xc2PJ\xe1\x13Xl\xc2\x0cs\r\x90L\xe0\x06\x1d\x0b\x83\x85f\x0e\x07\x07\x00\x1a\xd8P\x08be\xd1\xa6\xc1\xc6\\\n\x8d$\x89A@\xa0\x01\x84\xc1 \xd0\x81\x81\xc5\x98C\xd3\xac\xc2\x1d\x91\xd2X\xb7\x9f\xf9\x82\x80\r\xc4\xc0@II{\xe0(\xe4\xe4\xf5&[\x0b\x02\x85\x00\x03\xc0\xc0 qA\x19\xa0T\x03\x012i\xc8\xb4o\xf9\xda\xf3\xf4\x9f+w\x1d\x07r\x1b\x8dC\x94\xf6\xb3\xb7\x05\xc6\xdc\x86\x94\xde\xbe\xac\xb9\xc8i*\xf9\x9d\xc3\xcf\xe5<\xec\x06\xa1\xa9l\xb9\x00\x80%\xf2\xad\x96\x12\xd5\x81\xa7\x93v\xdbuZ\xf8\xd8\xc3&\xb1 \x97\xee\x9e\xdd&.\xfcF,\xf9+\xa5e~ \xba\xd8P\xd2\xb9p\xcb\xf9\x07R.\x89l\xf3\xe5Ku\xe6TI\xe7\'\x93 ...
